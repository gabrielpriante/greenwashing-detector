# %%
from pathlib import Path
import sys

# Figure out project root (one level up from notebooks/)
PROJECT_ROOT = Path("..").resolve()
SRC_DIR = PROJECT_ROOT / "src"

# Add src/ to Python's search path
sys.path.append(str(SRC_DIR))

from text_cleaning import basic_clean_text, tokenize
from greenwashing_scoring import simple_greenwashing_score

# %%
text = "Our eco-friendly product is 100% natural and chemical-free!"
simple_greenwashing_score(text)
# Out:
# {'score': 80,
#  'risk_level': 'High',
#  'matched_keywords': ['eco friendly', '100 natural', 'chemical free']}
